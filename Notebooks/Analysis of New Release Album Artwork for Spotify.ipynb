# %%
import os
from PIL import Image

# %%
# Function to analyze image
def analyze_image(image_path):
    # Open image and get dimensions
    image = Image.open(image_path)
    width, height = image.size
    
    # Get color palette
    palette = image.getpalette()
    
    # Count number of colors
    if palette is not None:
        color_count = len(palette) // 3
    else:
        color_count = len(set(image.getdata()))
    
    # Calculate aspect ratio
    aspect_ratio = width / height
    
    # Calculate color dominance
    pixel_count_list = list(image.getdata())
    color_dict = {}
    for pixel_count in pixel_count_list:
        if pixel_count not in color_dict:
            color_dict[pixel_count] = 1
        else:
            color_dict[pixel_count] += 1
    color_dominance = max(color_dict, key=color_dict.get)
    
    # Return analysis results as a dictionary
    analysis_results = {
        'filename': os.path.basename(image_path),
        'width': width,
        'height': height,
        'color_count': color_count,
        'aspect_ratio': aspect_ratio,
        'color_dominance': color_dominance
    }
    return analysis_results

# %%
# Set directory containing images
directory = 'output_images'

# Initialize list to store analysis results
analysis_results_list = []

# %%
# Loop through images in directory and analyze each one
for filename in os.listdir(directory):
    if filename.endswith('.jpg') or filename.endswith('.png'):
        image_path = os.path.join(directory, filename)
        analysis_results = analyze_image(image_path)
        analysis_results_list.append(analysis_results)

# %%
# Print analysis results for each image
for analysis_results in analysis_results_list:
    print('Filename:', analysis_results['filename'])
    print('Width:', analysis_results['width'])
    print('Height:', analysis_results['height'])
    print('Color count:', analysis_results['color_count'])
    print('Aspect ratio:', analysis_results['aspect_ratio'])
    print('Color dominance:', analysis_results['color_dominance'])
    print()
# Out:
# Filename: image_E10.jpg
# Width: 270
# Height: 271
# Color count: 5903
# Aspect ratio: 0.996309963099631
# Color dominance: (0, 0, 0)
#
# Filename: image_E11.jpg
# Width: 270
# Height: 271
# Color count: 13782
# Aspect ratio: 0.996309963099631
# Color dominance: (12, 12, 12)
#
# Filename: image_E12.jpg
# Width: 270
# Height: 271
# Color count: 26640
# Aspect ratio: 0.996309963099631
# Color dominance: (249, 206, 233)
#
# Filename: image_E13.jpg
# Width: 270
# Height: 271
# Color count: 14488
# Aspect ratio: 0.996309963099631
# Color dominance: (228, 228, 228)
#
# Filename: image_E14.jpg
# Width: 270
# Height: 271
# Color count: 17408
# Aspect ratio: 0.996309963099631
# Color dominance: (5, 1, 0)
#
# Filename: image_E15.jpg
# Width: 270
# Height: 272
# Color count: 21291
# Aspect ratio: 0.9926470588235294
# Color dominance: (23, 24, 29)
#
# Filename: image_E17.jpg
# Width: 270
# Height: 271
# Color count: 9116
# Aspect ratio: 0.996309963099631
# Color dominance: (205, 208, 223)
#
# Filename: image_E18.jpg
# Width: 270
# Height: 271
# Color count: 256
# Aspect ratio: 0.996309963099631
# Color dominance: (14, 14, 14)
#
# Filename: image_E19.jpg
# Width: 270
# Height: 271
# Color count: 38453
# Aspect ratio: 0.996309963099631
# Color dominance: (20, 29, 24)
#
# Filename: image_E2.jpg
# Width: 270
# Height: 271
# Color count: 26131
# Aspect ratio: 0.996309963099631
# Color dominance: (204, 189, 168)
#
# Filename: image_E20.jpg
# Width: 270
# Height: 272
# Color count: 21049
# Aspect ratio: 0.9926470588235294
# Color dominance: (1, 52, 83)
#
# Filename: image_E22.jpg
# Width: 270
# Height: 271
# Color count: 15817
# Aspect ratio: 0.996309963099631
# Color dominance: (1, 2, 4)
#
# Filename: image_E23.jpg
# Width: 270
# Height: 271
# Color count: 21829
# Aspect ratio: 0.996309963099631
# Color dominance: (221, 237, 188)
#
# Filename: image_E24.jpg
# Width: 270
# Height: 271
# Color count: 10828
# Aspect ratio: 0.996309963099631
# Color dominance: (0, 0, 0)
#
# Filename: image_E25.jpg
# Width: 270
# Height: 272
# Color count: 11040
# Aspect ratio: 0.9926470588235294
# Color dominance: (17, 17, 17)
#
# Filename: image_E26.jpg
# Width: 270
# Height: 272
# Color count: 12736
# Aspect ratio: 0.9926470588235294
# Color dominance: (33, 23, 21)
#
# Filename: image_E28.jpg
# Width: 270
# Height: 271
# Color count: 57214
# Aspect ratio: 0.996309963099631
# Color dominance: (234, 203, 175)
#
# Filename: image_E29.jpg
# Width: 270
# Height: 271
# Color count: 255
# Aspect ratio: 0.996309963099631
# Color dominance: (43, 43, 43)
#
# Filename: image_E3.jpg
# Width: 270
# Height: 271
# Color count: 46891
# Aspect ratio: 0.996309963099631
# Color dominance: (10, 8, 11)
#
# Filename: image_E30.jpg
# Width: 270
# Height: 272
# Color count: 8849
# Aspect ratio: 0.9926470588235294
# Color dominance: (0, 0, 0)
#
# Filename: image_E31.jpg
# Width: 270
# Height: 272
# Color count: 9171
# Aspect ratio: 0.9926470588235294
# Color dominance: (19, 27, 30)
#
# Filename: image_E33.jpg
# Width: 270
# Height: 271
# Color count: 39041
# Aspect ratio: 0.996309963099631
# Color dominance: (92, 32, 24)
#
# Filename: image_E34.jpg
# Width: 270
# Height: 271
# Color count: 36931
# Aspect ratio: 0.996309963099631
# Color dominance: (103, 81, 58)
#
# Filename: image_E35.jpg
# Width: 270
# Height: 272
# Color count: 54284
# Aspect ratio: 0.9926470588235294
# Color dominance: (4, 0, 0)
#
# Filename: image_E36.jpg
# Width: 270
# Height: 272
# Color count: 9304
# Aspect ratio: 0.9926470588235294
# Color dominance: (15, 15, 15)
#
# Filename: image_E38.jpg
# Width: 270
# Height: 271
# Color count: 19847
# Aspect ratio: 0.996309963099631
# Color dominance: (144, 112, 61)
#
# Filename: image_E39.jpg
# Width: 270
# Height: 271
# Color count: 32711
# Aspect ratio: 0.996309963099631
# Color dominance: (212, 210, 195)
#
# Filename: image_E4.jpg
# Width: 270
# Height: 271
# Color count: 49937
# Aspect ratio: 0.996309963099631
# Color dominance: (3, 4, 9)
#
# Filename: image_E40.jpg
# Width: 270
# Height: 272
# Color count: 24287
# Aspect ratio: 0.9926470588235294
# Color dominance: (6, 2, 1)
#
# Filename: image_E41.jpg
# Width: 270
# Height: 272
# Color count: 7913
# Aspect ratio: 0.9926470588235294
# Color dominance: (42, 38, 37)
#
# Filename: image_E43.jpg
# Width: 270
# Height: 271
# Color count: 21611
# Aspect ratio: 0.996309963099631
# Color dominance: (88, 81, 65)
#
# Filename: image_E44.jpg
# Width: 270
# Height: 271
# Color count: 27734
# Aspect ratio: 0.996309963099631
# Color dominance: (255, 255, 255)
#
# Filename: image_E45.jpg
# Width: 270
# Height: 272
# Color count: 16212
# Aspect ratio: 0.9926470588235294
# Color dominance: (217, 206, 204)
#
# Filename: image_E46.jpg
# Width: 270
# Height: 272
# Color count: 7485
# Aspect ratio: 0.9926470588235294
# Color dominance: (246, 249, 254)
#
# Filename: image_E48.jpg
# Width: 270
# Height: 272
# Color count: 10982
# Aspect ratio: 0.9926470588235294
# Color dominance: (10, 41, 72)
#
# Filename: image_E5.jpg
# Width: 270
# Height: 271
# Color count: 30668
# Aspect ratio: 0.996309963099631
# Color dominance: (2, 10, 13)
#
# Filename: image_E50.jpg
# Width: 270
# Height: 271
# Color count: 36448
# Aspect ratio: 0.996309963099631
# Color dominance: (43, 69, 92)
#
# Filename: image_E51.jpg
# Width: 270
# Height: 271
# Color count: 25224
# Aspect ratio: 0.996309963099631
# Color dominance: (16, 12, 13)
#
# Filename: image_E6.jpg
# Width: 270
# Height: 271
# Color count: 25199
# Aspect ratio: 0.996309963099631
# Color dominance: (0, 0, 0)
#
# Filename: image_E7.jpg
# Width: 270
# Height: 271
# Color count: 26461
# Aspect ratio: 0.996309963099631
# Color dominance: (5, 4, 2)
#
# Filename: image_E8.jpg
# Width: 270
# Height: 271
# Color count: 36029
# Aspect ratio: 0.996309963099631
# Color dominance: (3, 7, 8)
#
# Filename: image_E9.jpg
# Width: 270
# Height: 271
# Color count: 23739
# Aspect ratio: 0.996309963099631
# Color dominance: (25, 15, 14)
